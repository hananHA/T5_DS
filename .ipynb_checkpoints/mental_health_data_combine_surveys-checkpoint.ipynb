# %% [markdown]
# ## Combine Surveys
#
# This notebook is only about combining the data of surveys from 2014 to 2020

# %%
# Import needed modules
import pandas as pd
import re

# %%
# general function to drop columns
def drop_cols(dataFrame, cols, inplace):
    dataFrame.drop(cols, axis=1, inplace=inplace)

# %%
df2014 = pd.read_csv('mental_health_data/mental_health_in_tech_survey_2014.csv')
df2016 = pd.read_csv('mental_health_data/mental_health_in_tech_survey_2016.csv')
df2017 = pd.read_csv('mental_health_data/mental_health_in_tech_survey_2017.csv')
df2018 = pd.read_csv('mental_health_data/mental_health_in_tech_survey_2018.csv')
df2019 = pd.read_csv('mental_health_data/mental_health_in_tech_survey_2019.csv')
df2020 = pd.read_csv('mental_health_data/mental_health_in_tech_survey_2020.csv')

# %%
df_all = df2014.append(df2016, ignore_index=True)
df_all = df_all.append(df2017, ignore_index=True)
df_all = df_all.append(df2018, ignore_index=True)
df_all = df_all.append(df2019, ignore_index=True)
df_all = df_all.append(df2020, ignore_index=True)

# %%
df_all.head()
# Out:
#      # *Are you self-employed?* *Do you have previous employers?*  \
# 0  NaN                      NaN                               NaN
# 1  NaN                      NaN                               NaN
# 2  NaN                      NaN                               NaN
# 3  NaN                      NaN                               NaN
# 4  NaN                      NaN                               NaN
#
#   *If possibly, what disorder(s) do you believe you have?*  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   *If so, what disorder(s) were you diagnosed with?*  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
for col in df_all.columns:
    print(col)
# Out:
# #
# *Are you self-employed?*
# *Do you have previous employers?*
# *If possibly, what disorder(s) do you believe you have?*
# *If so, what disorder(s) were you diagnosed with?*
# *What disorder(s) have you been diagnosed with?*
# <strong>Are you self-employed?</strong>
# <strong>Do you have previous employers?</strong>
# <strong>Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?</strong>
# <strong>Have you observed or experienced supportive or well handled response to a mental health issue in your current or previous workplace?</strong>
# <strong>Have your previous employers provided mental health benefits?</strong>
# <strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?</strong>
# <strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?</strong>
# ...

# %%
drop_cols(df_all, ['#'], True)
for col in df_all.columns:
    new_col = re.sub('\W+',' ', col)
    new_col = new_col.replace('strong', '')
    new_col = new_col.strip()
    new_col = new_col.replace('issues', 'disorders')
    new_col = new_col.replace('issue', 'disorder')
    new_col = new_col.replace('  live', ' live')
    new_col = new_col.replace('  work', ' work')
    new_col = new_col.replace('  in', ' in')
    df_all.rename(columns = {col: new_col}, inplace=True)

# %%
df_all.head()
# Out:
#    Are you self employed  Do you have previous employers  \
# 0                    NaN                             NaN
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                             NaN
#
#   If possibly what disorder s do you believe you have  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   If so what disorder s were you diagnosed with  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
# ...

# %%
for col in df_all.columns:
    print(col)
# Out:
# Are you self employed
# Do you have previous employers
# If possibly what disorder s do you believe you have
# If so what disorder s were you diagnosed with
# What disorder s have you been diagnosed with
# Are you self employed
# Do you have previous employers
# Have you observed or experienced an unsupportive or badly handled response to a mental health disorder in your current or previous workplace
# Have you observed or experienced supportive or well handled response to a mental health disorder in your current or previous workplace
# Have your previous employers provided mental health benefits
# If you have been diagnosed or treated for a mental health disorder do you ever reveal this to clients or business contacts
# If you have been diagnosed or treated for a mental health disorder do you ever reveal this to coworkers or employees
# Were you aware of the options for mental health care provided by your previous employers
# ...

# %%
# show that we have dublicated colmuns after cleaning the columns names
df_all['Are you self employed']
# Out:
#      Are you self employed Are you self employed Are you self employed
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# 5                      NaN                   NaN                   NaN
# 6                      NaN                   NaN                   NaN
# 7                      NaN                   NaN                   NaN
# 8                      NaN                   NaN                   NaN
# 9                      NaN                   NaN                   NaN
# 10                     NaN                   NaN                   NaN
# 11                     NaN                   NaN                   NaN
# ...

# %%
# group by dublicated columns
df = df_all.groupby(df_all.columns, axis=1).first()

# %%
# check combined colmun
df['Are you self employed']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      Yes
# 19      Yes
# 20       No
# 21      Yes
# 22       No
# 23       No
# 24       No
# 25       No
# 26       No
# 27       No
# 28       No
# 29       No
#        ...
# 4368      0
# 4369      0
# 4370      0
# 4371      0
# 4372      0
# 4373      0
# 4374      0
# 4375      0
# 4376      0
# 4377      0
# 4378      0
# 4379      0
# 4380      0
# 4381      0
# 4382      0
# 4383      0
# 4384      0
# 4385      0
# 4386      0
# 4387      0
# 4388      0
# 4389      0
# 4390      0
# 4391      0
# 4392      0
# 4393      0
# 4394      0
# 4395      0
# 4396      0
# 4397      0
# Name: Are you self employed, Length: 4398, dtype: object

# %%
df.head()
# Out:
#    Addictive Disorder Addictive Disorder 1 Addictive Disorder 2   Age  \
# 0                 NaN                  NaN                  NaN  37.0
# 1                 NaN                  NaN                  NaN  44.0
# 2                 NaN                  NaN                  NaN  32.0
# 3                 NaN                  NaN                  NaN  31.0
# 4                 NaN                  NaN                  NaN  31.0
#
#    Anxiety Disorder Generalized Social Phobia etc  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Anxiety Disorder Generalized Social Phobia etc 1  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# ...

# %% [markdown]
# ### Combine same-meaning-indicating columns
# This part is to only to combine the columns that have the same meaning of a question or the same question

# %%
for col in df.columns:
    print(col)
# Out:
# Addictive Disorder
# Addictive Disorder 1
# Addictive Disorder 2
# Age
# Anxiety Disorder Generalized Social Phobia etc
# Anxiety Disorder Generalized Social Phobia etc 1
# Anxiety Disorder Generalized Social Phobia etc 2
# Any additional notes or comments
# Are you openly identified at work as a person with a mental health disorder
# Are you self employed
# Attention Deficit Hyperactivity Disorder
# Attention Deficit Hyperactivity Disorder 1
# Attention Deficit Hyperactivity Disorder 2
# Briefly describe what you think the industry as a whole and or employers could do to improve mental health support for employees
# Country
# Describe the circumstances of the badly handled or unsupportive response
# Describe the circumstances of the supportive or well handled response
# Describe the conversation with coworkers you had about your mental health including their reactions
# ...

# %%
# COL: age
    # Age
    # What is your age

# COL: country
    # Country
    # What country do you live in
    # What country do you work in

# COL: gender
    # Gender
    # What is your gender

# COL: self_employed
    # Are you self employed

# COL: remote_work
    # Do you work remotely
    # Do you work remotely outside of an office at least 50 of the time

# COL: race
    # What is your race

# COL: IT_related_job
    # Is your primary role within your company related to tech IT

# COL: disorders
    # Disorders
    # Stress Response Syndromes
    # If yes what condition s have you been diagnosed with

# COL: affected_productivity
    # Do you believe your productivity is ever affected by a mental health disorder

# COL: family_history
    # Do you have a family history of mental illness

# COL: no_employees
    # How many employees does your company or organization have

# COL: neg_consequences
    # Did you hear of or observe negative consequences for co workers with mental health disorders in your previous workplaces
    # Do you think that discussing a mental health disorder with previous employers would have negative consequences
    # Do you think that discussing a mental health disorder with your employer would have negative consequences
    # Do you think that discussing a physical health disorder with previous employers would have negative consequences
    # Do you think that discussing a physical health disorder with your employer would have negative consequences
    # Do you think that team members co workers would view you more negatively if they knew you suffered from a mental health disorder

# COL: career_damage
    # Do you feel that being identified as a person with a mental health disorder would hurt your career
    # Has being identified as a person with a mental health disorder affected your career

# COL: care_about_mental_health
    # Do you feel that your employer takes mental health as seriously as physical health

# COL: shared_resources
    # Does your employer offer resources to learn more about mental health concerns and options for seeking help
    # Does your employer offer resources to learn more about mental health disorders and options for seeking help
    # Does your employer provide resources to learn more about mental health disorders and how to seek help


# COL: wellness_program
    # Has your employer ever discussed mental health as part of an employee wellness program
    # Has your employer ever formally discussed mental health for example as part of a wellness campaign or other official communication

# COL: tech_industry_support
    # Overall how well do you think the tech industry supports employees with mental health disorders

# COL: mental_importance
    # Overall how much importance did your previous employer place on mental health
    # Overall how much importance does your employer place on mental health

# COL: physical_importance
    # Overall how much importance did your previous employer place on physical health
    # Overall how much importance does your employer place on physical health

# COL: reveal_disorder
    # If you have been diagnosed or treated for a mental health disorder do you ever reveal this to clients or business contacts
    # If you have been diagnosed or treated for a mental health disorder do you ever reveal this to coworkers or employees

# COL: reveal_neg_impact
    # If you have revealed a mental health disorder to a client or business contact do you believe this has impacted you negatively
    # If you have revealed a mental health disorder to a client or business contact how has this affected you or the relationship
    # If you have revealed a mental health disorder to a coworker or employee do you believe this has impacted you negatively
    # If you have revealed a mental health disorder to a coworker or employee how has this impacted you or the relationship


# COL: talk_to_supervisors
    # Would you have been willing to discuss a mental health disorder with your direct supervisor s
    # Would you have been willing to discuss your mental health with your direct supervisor s
    # Would you have felt more comfortable talking to your previous employer about your physical health or your mental health
    # Would you feel comfortable discussing a mental health disorder with your direct supervisor s
    # Would you be willing to discuss a mental health disorder with your direct supervisor s
    # Did you ever discuss your mental health with your previous employer
    # Have you ever discussed your mental health with your employer

# COL: talk_to_coworkers
    # Would you have been willing to discuss a mental health disorder with your previous co workers
    # Would you have been willing to discuss your mental health with your coworkers at previous employers
    # Would you feel more comfortable talking to your coworkers about your physical health or your mental health
    # Would you feel comfortable discussing a mental health disorder with your coworkers
    # Would you be willing to discuss a mental health disorder with your coworkers
    # Did you ever discuss your mental health with a previous coworker s
    # Have you ever discussed your mental health with coworkers

# COL: interview_mental
    # Would you bring up your mental health with a potential employer in an interview
    # Would you bring up a mental health disorder with a potential employer in an interview

# COL: interview_physical
    # Would you bring up a physical health disorder with a potential employer in an interview
    # Would you be willing to bring up a physical health disorder with a potential employer in an interview

# COL: tech_organization
    # Was your employer primarily a tech company organization
    # Is your employer primarily a tech company organization

# COL: care_coverage
    # Were you aware of the options for mental health care provided by your previous employers
    # Do you know the options for mental health care available under your employer provided coverage
    # Do you know the options for mental health care available under your employer provided health coverage
    # Do you know the options for mental health care your employer provides
    # Have your previous employers provided mental health benefits
    # How easy is it for you to take medical leave for a mental health condition
    # Do you have medical coverage private insurance or state provided that includes treatment of mental health disorders
    # Does your employer provide mental health benefits


# COL: work_interfere
    # If you have a mental health disorder how often do you feel that it interferes with your work  when  em  NOT  em  being treated effectively i e when you are experiencing symptoms
    # If you have a mental health disorder how often do you feel that it interferes with your work  when being treated effectively
    # If you have a mental health disorder how often do you feel that it interferes with your work  when em NOT em being treated effectively i e when you are experiencing symptoms
    # If you have a mental health disorder how often do you feel that it interferes with your work when _ NOT _ being treated effectively i e when you are experiencing symptoms
    # If you have a mental health disorder how often do you feel that it interferes with your work when being treated effectively
    # If you have a mental health condition do you feel that it interferes with your work
    # If you have a mental health disorder do you feel that it interferes with your work when NOT being treated effectively
    # If you have a mental health disorder do you feel that it interferes with your work when being treated effectively

# COL: treated
    # Are you openly identified at work as a person with a mental health disorder
    # Do you currently have a mental health disorder
    # Have you been diagnosed with a mental health condition by a medical professional
    # Have you ever been diagnosed with a mental health disorder
    # Have you ever sought treatment for a mental health disorder from a mental health professional
    # Have you had a mental health disorder in the past
    # Have you sought treatment for a mental health condition

# COL: privacy
    # Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers
    # Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources





# ----TO DROP----:
    # Submit Date UTC
    # Timestamp
    # Start Date UTC
    # Network ID
    # What US state or territory do you live in
    # What US state or territory do you work in
    # If you live in the United States which state or territory do you live in
    # Any additional notes or comments
    # Briefly describe what you think the industry as a whole and or employers could do to improve mental health support for employees
    # Describe the circumstances of the badly handled or unsupportive response
    # Describe the circumstances of the supportive or well handled response
    # Describe the conversation with coworkers you had about your mental health including their reactions
    # Describe the conversation you had with your employer about your mental health including their reactions and what actions were taken to address your mental health disorder questions
    # Describe the conversation you had with your previous coworkers about your mental health including their reactions
    # Describe the conversation you had with your previous employer about your mental health including their reactions and actions taken to address your mental health disorder questions
    # Describe the conversation your coworker had with you about their mental health please do not use names
    # Do you have previous employers
    # How willing would you be to share with friends and family that you have a mental illness
    # Why or why not
    # If a mental health disorder prompted you to request a medical leave from work asking for that leave would be
    # If a mental health disorder prompted you to request a medical leave from work how easy or difficult would it be to ask for that leave
    # If there is anything else you would like to tell us that has not been covered by the survey questions please use this space to do so
    # If they knew you suffered from a mental health disorder how do you think that team members co workers would react
    # If they knew you suffered from a mental health disorder how do you think that your team members co workers would react
    # Have you ever had a coworker discuss their or another coworker s mental health with you
    # If yes what percentage of your work time time performing primary or secondary job functions is affected by a mental health disorder
    # How has it affected your career
    # Did you ever have a previous coworker discuss their or another coworker s mental health with you
    # Did you feel that your previous employers took mental health as seriously as physical health
    # Have you heard of or observed negative consequences for co workers who have been open about mental health disorders in your workplace
    # Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace
    # Did your previous employers ever formally discuss mental health as part of a wellness campaign or other official communication
    # Did your previous employers provide resources to learn more about mental health disorders and how to seek help
    # Do you know local or online resources to seek help for a mental health disorder
    # Other
    # Would you be willing to talk to one of us more extensively about your experiences with mental health disorders in the tech industry Note that all interview responses would be used _anonymously_ and only with your permission
    # Would you be willing to talk to one of us more extensively about your experiences with mental health disorders in the tech industry Note that all interview responses would be used em anonymously em and only with your permission
    # Have you observed or experienced a supportive or well handled response to a mental health disorder in your current or previous workplace
    # Have you observed or experienced an unsupportive or badly handled response to a mental health disorder in your current or previous workplace
    # Have you observed or experienced supportive or well handled response to a mental health disorder in your current or previous workplace
    # Have your observations of how another individual who discussed a mental health disorder made you less likely to reveal a mental health disorder yourself in your current workplace
    # Which of the following best describes your work position

# %%
# COL: disorders
disorders_cols = ['Psychotic Disorder Schizophrenia Schizoaffective etc', 
                  'Psychotic Disorder Schizophrenia Schizoaffective etc 1', 
                  'Psychotic Disorder Schizophrenia Schizoaffective etc 2', 
                  'What disorder s have you been diagnosed with', 
                  'If so what disorder s were you diagnosed with', 
                  'If so what condition s were you diagnosed with', 
                  'If possibly what disorder s do you believe you have', 
                  'If maybe what condition s do you believe you have', 
                  'Anxiety Disorder Generalized Social Phobia etc', 
                  'Anxiety Disorder Generalized Social Phobia etc 1', 
                  'Anxiety Disorder Generalized Social Phobia etc 2', 
                  'Addictive Disorder', 
                  'Addictive Disorder 1',
                  'Addictive Disorder 2',
                  'Attention Deficit Hyperactivity Disorder', 
                  'Attention Deficit Hyperactivity Disorder 1', 
                  'Attention Deficit Hyperactivity Disorder 2', 
                  'Dissociative Disorder', 
                  'Dissociative Disorder 1', 
                  'Dissociative Disorder 2', 
                  'Substance Use Disorder', 
                  'Substance Use Disorder 1', 
                  'Substance Use Disorder 2', 
                  'Eating Disorder Anorexia Bulimia etc', 
                  'Eating Disorder Anorexia Bulimia etc 1', 
                  'Eating Disorder Anorexia Bulimia etc 2', 
                  'Obsessive Compulsive Disorder', 
                  'Obsessive Compulsive Disorder 1', 
                  'Obsessive Compulsive Disorder 2', 
                  'Mood Disorder Depression Bipolar Disorder etc', 
                  'Mood Disorder Depression Bipolar Disorder etc 1', 
                  'Mood Disorder Depression Bipolar Disorder etc 2', 
                  'Personality Disorder Borderline Antisocial Paranoid etc', 
                  'Personality Disorder Borderline Antisocial Paranoid etc 1', 
                  'Personality Disorder Borderline Antisocial Paranoid etc 2', 
                  'Post Traumatic Stress Disorder', 
                  'Post traumatic Stress Disorder',
                  'Post traumatic Stress Disorder 1',
                  'Stress Response Syndromes', 
                  'Stress Response Syndromes 1', 
                  'Stress Response Syndromes 2', 
                  'If yes what condition s have you been diagnosed with']
df['disorders'] = df[disorders_cols[0]]
for i in range(len(disorders_cols) - 1):
    df['disorders'] = df['disorders'].fillna(df[disorders_cols[i+1]])
drop_cols(df, disorders_cols, True)

# %%
df
# Out:
#        Age                   Any additional notes or comments  \
# 0     37.0                                                NaN
# 1     44.0                                                NaN
# 2     32.0                                                NaN
# 3     31.0                                                NaN
# 4     31.0                                                NaN
# 5     33.0                                                NaN
# 6     35.0                                                NaN
# 7     39.0                                                NaN
# 8     42.0                                                NaN
# 9     23.0                                                NaN
# 10    31.0                                                NaN
# 11    29.0                                                NaN
# 12    42.0                                                NaN
# 13    36.0  I'm not on my company's health insurance, whic...
# ...

# %%
df['age'] = df['Age'].fillna(df['What is your age'])
df['gender'] = df['Gender'].fillna(df['What is your gender'])
df['country'] = df['Country'].fillna(df['What country do you live in']).fillna(df['What country do you work in'])
drop_cols(df, ['Age', 'What is your age', 'Gender', 'What is your gender', 'Country', 'What country do you live in', 'What country do you work in'], True)

# %%
df
# Out:
#                        Any additional notes or comments  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13    I'm not on my company's health insurance, whic...
# 14                                                  NaN
# 15    I have chronic, low-level neurological issues ...
# ...

# %%
# COL: privacy
privacy_cols = ['Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers',
                'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources',
                'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer']
df['privacy'] = df[privacy_cols[0]]
for i in range(len(privacy_cols) - 1):
    df['privacy'] = df['privacy'].fillna(df[privacy_cols[i+1]])
drop_cols(df, privacy_cols, True)

# %%
# COL: treated
treated_cols = ['Are you openly identified at work as a person with a mental health disorder',
                'Do you currently have a mental health disorder',
                'Have you been diagnosed with a mental health condition by a medical professional',
                'Have you ever been diagnosed with a mental health disorder',
                'Have you ever sought treatment for a mental health disorder from a mental health professional',
                'Have you had a mental health disorder in the past',
                'Have you sought treatment for a mental health condition']
df['treated'] = df[treated_cols[0]]
for i in range(len(treated_cols) - 1):
    df['treated'] = df['treated'].fillna(df[treated_cols[i+1]])
drop_cols(df, treated_cols, True)

# %%
# COL: work_interfere
work_interfere_cols = ['If you have a mental health disorder how often do you feel that it interferes with your work  when  em  NOT  em  being treated effectively i e when you are experiencing symptoms',
                'If you have a mental health disorder how often do you feel that it interferes with your work  when being treated effectively',
                'If you have a mental health disorder how often do you feel that it interferes with your work  when em NOT em being treated effectively i e when you are experiencing symptoms',
                'If you have a mental health disorder how often do you feel that it interferes with your work when _ NOT _ being treated effectively i e when you are experiencing symptoms',
                'If you have a mental health disorder how often do you feel that it interferes with your work when being treated effectively',
                'If you have a mental health condition do you feel that it interferes with your work',
                'If you have a mental health disorder do you feel that it interferes with your work when NOT being treated effectively',
                'If you have a mental health disorder do you feel that it interferes with your work when being treated effectively']
df['work_interfere'] = df[work_interfere_cols[0]]
for i in range(len(work_interfere_cols) - 1):
    df['work_interfere'] = df['work_interfere'].fillna(df[work_interfere_cols[i+1]])
drop_cols(df, work_interfere_cols, True)

# %%
# COL: care_coverage 
care_coverage_cols = ['Were you aware of the options for mental health care provided by your previous employers',
                'Do you know the options for mental health care available under your employer provided coverage',
                'Do you know the options for mental health care available under your employer provided health coverage',
                'Do you know the options for mental health care your employer provides',
                'Have your previous employers provided mental health benefits',
                'How easy is it for you to take medical leave for a mental health condition',
                'Do you have medical coverage private insurance or state provided that includes treatment of mental health disorders',
                'Do you have medical coverage private insurance or state provided which includes treatment of mental health disorders',
                'Does your employer provide mental health benefits',
                'Does your employer provide mental health benefits as part of healthcare coverage']
df['care_coverage'] = df[care_coverage_cols[0]]
for i in range(len(care_coverage_cols) - 1):
    df['care_coverage'] = df['care_coverage'].fillna(df[care_coverage_cols[i+1]])
drop_cols(df, care_coverage_cols, True)

# %%
# COL: talk_to_coworkers
talk_to_coworkers_cols = ['Would you have been willing to discuss a mental health disorder with your previous co workers',
                'Would you have been willing to discuss your mental health with your coworkers at previous employers',
                'Would you feel more comfortable talking to your coworkers about your physical health or your mental health',
                'Would you feel comfortable discussing a mental health disorder with your coworkers',
                'Would you be willing to discuss a mental health disorder with your coworkers',
                'Did you ever discuss your mental health with a previous coworker s',
                'Have you ever discussed your mental health with coworkers']
df['talk_to_coworkers'] = df[talk_to_coworkers_cols[0]]
for i in range(len(talk_to_coworkers_cols) - 1):
    df['talk_to_coworkers'] = df['talk_to_coworkers'].fillna(df[talk_to_coworkers_cols[i+1]])
drop_cols(df, talk_to_coworkers_cols, True)

# %%
# COL: talk_to_supervisors
talk_to_supervisors_cols = ['Would you have been willing to discuss a mental health disorder with your direct supervisor s',
                'Would you have been willing to discuss your mental health with your direct supervisor s',
                'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health',
                'Would you feel comfortable discussing a mental health disorder with your direct supervisor s',
                'Would you be willing to discuss a mental health disorder with your direct supervisor s',
                'Did you ever discuss your mental health with your previous employer',
                'Have you ever discussed your mental health with your employer']
df['talk_to_supervisors'] = df[talk_to_supervisors_cols[0]]
for i in range(len(talk_to_supervisors_cols) - 1):
    df['talk_to_supervisors'] = df['talk_to_supervisors'].fillna(df[talk_to_supervisors_cols[i+1]])
drop_cols(df, talk_to_supervisors_cols, True)

# %%
# COL: tech_organization
tech_organization_cols = ['Was your employer primarily a tech company organization',
                'Is your employer primarily a tech company organization']
df['tech_organization'] = df[tech_organization_cols[0]]
df['tech_organization'] = df['tech_organization'].fillna(df[tech_organization_cols[1]])
drop_cols(df, tech_organization_cols, True)

# %%
# COL: interview_physical
interview_physical_cols = ['Would you bring up a physical health disorder with a potential employer in an interview',
                'Would you be willing to bring up a physical health disorder with a potential employer in an interview']
df['interview_physical'] = df[interview_physical_cols[0]]
df['interview_physical'] = df['interview_physical'].fillna(df[interview_physical_cols[1]])
drop_cols(df, interview_physical_cols, True)

# %%
# COL: interview_mental
interview_mental_cols = ['Would you bring up your mental health with a potential employer in an interview',
                'Would you bring up a mental health disorder with a potential employer in an interview']
df['interview_mental'] = df[interview_mental_cols[0]]
df['interview_mental'] = df['interview_mental'].fillna(df[interview_mental_cols[1]])
drop_cols(df, interview_mental_cols, True)

# %%
# COL: reveal_disorder
reveal_disorder_cols = ['If you have been diagnosed or treated for a mental health disorder do you ever reveal this to clients or business contacts',
                'If you have been diagnosed or treated for a mental health disorder do you ever reveal this to coworkers or employees']
df['reveal_disorder'] = df[reveal_disorder_cols[0]]
df['reveal_disorder'] = df['reveal_disorder'].fillna(df[reveal_disorder_cols[1]])
drop_cols(df, reveal_disorder_cols, True)

# %%
# COL: reveal_neg_impact
reveal_neg_impact_cols = ['If you have revealed a mental health disorder to a client or business contact do you believe this has impacted you negatively',
                          'If you have revealed a mental health disorder to a client or business contact how has this affected you or the relationship',
                          'If you have revealed a mental health disorder to a coworker or employee do you believe this has impacted you negatively',
                          'If you have revealed a mental health disorder to a coworker or employee how has this impacted you or the relationship']
df['reveal_neg_impact'] = df[reveal_neg_impact_cols[0]]
for i in range(len(reveal_neg_impact_cols) - 1):
    df['reveal_neg_impact'] = df['reveal_neg_impact'].fillna(df[reveal_neg_impact_cols[i+1]])
drop_cols(df, reveal_neg_impact_cols, True)

# %%
# COL: neg_consequences
neg_consequences_cols = ['Did you hear of or observe negative consequences for co workers with mental health disorders in your previous workplaces',
                          'Do you think that discussing a mental health disorder with previous employers would have negative consequences',
                          'Do you think that discussing a mental health disorder with your employer would have negative consequences',
                          'Do you think that discussing a physical health disorder with previous employers would have negative consequences',
                        'Do you think that discussing a physical health disorder with your employer would have negative consequences',
                        'Do you think that team members co workers would view you more negatively if they knew you suffered from a mental health disorder']
df['neg_consequences'] = df[neg_consequences_cols[0]]
for i in range(len(neg_consequences_cols) - 1):
    df['neg_consequences'] = df['neg_consequences'].fillna(df[neg_consequences_cols[i+1]])
drop_cols(df, neg_consequences_cols, True)

# %%
# COL: career_damage
career_damage_cols = ['Do you feel that being identified as a person with a mental health disorder would hurt your career',
                'Has being identified as a person with a mental health disorder affected your career']
df['career_damage'] = df[career_damage_cols[0]]
df['career_damage'] = df['career_damage'].fillna(df[career_damage_cols[1]])
drop_cols(df, career_damage_cols, True)

# %%
# COL: wellness_program
wellness_program_cols = ['Has your employer ever discussed mental health as part of an employee wellness program',
                'Has your employer ever formally discussed mental health for example as part of a wellness campaign or other official communication']
df['wellness_program'] = df[wellness_program_cols[0]]
df['wellness_program'] = df['wellness_program'].fillna(df[wellness_program_cols[1]])
drop_cols(df, wellness_program_cols, True)

# %%
# COL: shared_resources
shared_resources_cols = ['Does your employer offer resources to learn more about mental health concerns and options for seeking help',
                'Does your employer offer resources to learn more about mental health disorders and options for seeking help',
                        'Does your employer provide resources to learn more about mental health disorders and how to seek help']
df['shared_resources'] = df[shared_resources_cols[0]]
for i in range(len(shared_resources_cols) - 1):
    df['shared_resources'] = df['shared_resources'].fillna(df[shared_resources_cols[i+1]])
drop_cols(df, shared_resources_cols, True)

# %%
# COL: mental_importance
mental_importance_cols = ['Overall how much importance did your previous employer place on mental health',
                'Overall how much importance does your employer place on mental health']
df['mental_importance'] = df[mental_importance_cols[0]]
df['mental_importance'] = df['mental_importance'].fillna(df[mental_importance_cols[1]])
drop_cols(df, mental_importance_cols, True)

# %%
# COL: physical_importance
physical_importance_cols = ['Overall how much importance did your previous employer place on physical health',
                'Overall how much importance does your employer place on physical health']
df['physical_importance'] = df[physical_importance_cols[0]]
df['physical_importance'] = df['physical_importance'].fillna(df[physical_importance_cols[1]])
drop_cols(df, physical_importance_cols, True)

# %%
# COL: remote_work
remote_work_cols = ['Do you work remotely',
                'Do you work remotely outside of an office at least 50 of the time']
df['remote_work'] = df[remote_work_cols[0]]
df['remote_work'] = df['remote_work'].fillna(df[remote_work_cols[1]])
drop_cols(df, remote_work_cols, True)

# %%
renamed = {
    'Are you self employed': 'self_employed',
    'What is your race': 'race',
    'Is your primary role within your company related to tech IT': 'IT_related_job',
    'Do you believe your productivity is ever affected by a mental health disorder': 'affected_productivity',
    'Do you have a family history of mental illness': 'family_history',
    'How many employees does your company or organization have': 'no_employees',
    'Do you feel that your employer takes mental health as seriously as physical health': 'care_about_mental_health',
    'Overall how well do you think the tech industry supports employees with mental health disorders': 'tech_industry_support'
}
df.rename(columns=renamed, inplace=True)

# %%
cols_to_drop = ['Submit Date UTC',
                'Timestamp',
                'Start Date UTC',
                'Network ID',
                'What US state or territory do you live in',
                'What US state or territory do you work in',
                'If you live in the United States which state or territory do you live in',
                'Any additional notes or comments',
                'Briefly describe what you think the industry as a whole and or employers could do to improve mental health support for employees',
                'Describe the circumstances of the badly handled or unsupportive response',
                'Describe the circumstances of the supportive or well handled response',
                'Describe the conversation with coworkers you had about your mental health including their reactions',
                'Describe the conversation you had with your employer about your mental health including their reactions and what actions were taken to address your mental health disorder questions',
                'Describe the conversation you had with your previous coworkers about your mental health including their reactions',
                'Describe the conversation you had with your previous employer about your mental health including their reactions and actions taken to address your mental health disorder questions',
                'Describe the conversation your coworker had with you about their mental health please do not use names',
                'Describe the conversation your coworker had with you about their mental health please do not use names 1',
                'Do you have previous employers',
                'How willing would you be to share with friends and family that you have a mental illness',
                'Why or why not',
                'Why or why not 1',
                'If a mental health disorder prompted you to request a medical leave from work asking for that leave would be',
                'If a mental health disorder prompted you to request a medical leave from work how easy or difficult would it be to ask for that leave',
                'If there is anything else you would like to tell us that has not been covered by the survey questions please use this space to do so',
                'If they knew you suffered from a mental health disorder how do you think that team members co workers would react',
                'If they knew you suffered from a mental health disorder how do you think that your team members co workers would react',
                'Have you ever had a coworker discuss their or another coworker s mental health with you',
                'If yes what percentage of your work time time performing primary or secondary job functions is affected by a mental health disorder',
                'How has it affected your career',
                'Did you ever have a previous coworker discuss their or another coworker s mental health with you',
                'Did you feel that your previous employers took mental health as seriously as physical health',
                'Have you heard of or observed negative consequences for co workers who have been open about mental health disorders in your workplace',
                'Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace',
                'Did your previous employers ever formally discuss mental health as part of a wellness campaign or other official communication',
                'Did your previous employers provide resources to learn more about mental health disorders and how to seek help',
                'Do you know local or online resources to seek help for a mental health disorder',
                'Other',
                'Other 1',
                'Other 2',
                'Other 3',
                'Would you be willing to talk to one of us more extensively about your experiences with mental health disorders in the tech industry Note that all interview responses would be used _anonymously_ and only with your permission',
                'Would you be willing to talk to one of us more extensively about your experiences with mental health disorders in the tech industry Note that all interview responses would be used em anonymously em and only with your permission',
                'Have you observed or experienced a supportive or well handled response to a mental health disorder in your current or previous workplace',
                'Have you observed or experienced an unsupportive or badly handled response to a mental health disorder in your current or previous workplace',
                'Have you observed or experienced supportive or well handled response to a mental health disorder in your current or previous workplace',
                'Have your observations of how another individual who discussed a mental health disorder made you less likely to reveal a mental health disorder yourself in your current workplace',
                'Which of the following best describes your work position']
drop_cols(df, cols_to_drop, True)
df.head()
# Out:
#   self_employed affected_productivity care_about_mental_health family_history  \
# 0           NaN                   NaN                      Yes             No
# 1           NaN                   NaN               Don't know             No
# 2           NaN                   NaN                       No             No
# 3           NaN                   NaN                       No            Yes
# 4           NaN                   NaN               Don't know             No
#
#      no_employees IT_related_job  tech_industry_support race disorders   age  \
# 0            6-25            NaN                    NaN  NaN       NaN  37.0
# 1  More than 1000            NaN                    NaN  NaN       NaN  44.0
# 2            6-25            NaN                    NaN  NaN       NaN  32.0
# 3          26-100            NaN                    NaN  NaN       NaN  31.0
# 4         100-500            NaN                    NaN  NaN       NaN  31.0
#
# ...

# %% [markdown]
# ### Save combined surveys

# %%
# save combined surveys to csv file
df.to_csv('mental_health_data/mental_health_in_tech_survey_combined.csv')
